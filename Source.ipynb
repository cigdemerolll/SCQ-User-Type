# %%
import json
import pandas as pd
from html.parser import HTMLParser
import string

# %%
tweets = []
for line in open('/Users/cigdemerol/Downloads/Total Merge userobjects_01.07.2021 - Ozgem (1).json', 'r'):
    try:
      tweets.append(json.loads(line))
    except Exception as e:
      pass

# %%
from pandas import json_normalize

# %%
json_normalize(tweets)

# %%
tweets_new = json_normalize(tweets)

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>"] = 'Twitter Web App'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>"] = 'Twitter for Android'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>"] = 'Twitter for iPhone'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"https://periscope.tv\" rel=\"nofollow\">Periscope</a>"] = 'Periscope'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>"] = 'TweetDeck'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://foursquare.com\" rel=\"nofollow\">Foursquare</a>"] = 'Foursquare'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>"] = 'Twitter Web Client'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>"] = 'Twitter for iPad'

# %%
#instagram?
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>"] = 'Instagram'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://www.cloudhopper.com/\" rel=\"nofollow\">Twitter SMS</a>"] = 'Twitter SMS'

# %%
tweets_new.loc[tweets_new['status.source'] == "<a href=\"http://fllwrs.com\" rel=\"nofollow\">fllwrs</a>"] = 'fllwrs'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
tweets_new.head()
# Out:
#                     id               id_str                  name  \
# 0  1377260947631398913  1377260947631398913               Taha Öz
# 1   Twitter for iPhone   Twitter for iPhone    Twitter for iPhone
# 2  1377257157888987141  1377257157888987141  cburakucar@gmail.com
# 3      Twitter Web App      Twitter Web App       Twitter Web App
# 4   Twitter for iPhone   Twitter for iPhone    Twitter for iPhone
#
#           screen_name            location         description  \
# 0       Tahaz16002672
# 1  Twitter for iPhone  Twitter for iPhone  Twitter for iPhone
# 2          cburakucar
# 3     Twitter Web App     Twitter Web App     Twitter Web App
# 4  Twitter for iPhone  Twitter for iPhone  Twitter for iPhone
#
#                   url           protected     followers_count  \
# 0                None               False                   0
# 1  Twitter for iPhone  Twitter for iPhone  Twitter for iPhone
# 2                None               False                   1
# ...

# %%
tweets_new['status.source']

# %%
mydf.usersource.valuecounts()
